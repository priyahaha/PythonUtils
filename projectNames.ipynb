# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
import csv

with open('/content/drive/MyDrive/ml/projectNamesInput.csv', 'w', newline='') as csvfile:
    fieldnames = ['projectName']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    df=pd.read_csv('/content/drive/MyDrive/ml/projectNames.csv')
    projectnames = df['projectname']
    for i in projectnames :
      project = i.split('/')[1]
      print(project)
      string = 'projectName'
      writer.writerow({'projectName': project})
# Out:
# Streaming output truncated to the last 5000 lines.
# Sequencer
# Sequencer
# API_Mock_Server
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# CreateWorkOrder
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# Life_insurance
# API_Mock_Server
# API_Mock_Server
# API_Mock_Server
# API_Mock_Server
# API_Mock_Server
# API_Mock_Server
# CreateWorkOrder
# Vacation_Manegement
# Vacation_Manegement
# Vacation_Manegement
# Vacation_Manegement
# Vacation_Manegement
# Vacation_Manegement
# Vacation_Manegement
# Vacation_Manegement
# ...
